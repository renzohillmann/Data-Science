# %% [markdown]
# # Assignment 4
# ## Description
# In this assignment you must read in a file of metropolitan regions and associated sports teams from [assets/wikipedia_data.html](assets/wikipedia_data.html) and answer some questions about each metropolitan region. Each of these regions may have one or more teams from the "Big 4": NFL (football, in [assets/nfl.csv](assets/nfl.csv)), MLB (baseball, in [assets/mlb.csv](assets/mlb.csv)), NBA (basketball, in [assets/nba.csv](assets/nba.csv) or NHL (hockey, in [assets/nhl.csv](assets/nhl.csv)). Please keep in mind that all questions are from the perspective of the metropolitan region, and that this file is the "source of authority" for the location of a given sports team. Thus teams which are commonly known by a different area (e.g. "Oakland Raiders") need to be mapped into the metropolitan region given (e.g. San Francisco Bay Area). This will require some human data understanding outside of the data you've been given (e.g. you will have to hand-code some names, and might need to google to find out where teams are)!
#
# For each sport I would like you to answer the question: **what is the win/loss ratio's correlation with the population of the city it is in?** Win/Loss ratio refers to the number of wins over the number of wins plus the number of losses. Remember that to calculate the correlation with [`pearsonr`](https://docs.scipy.org/doc/scipy/reference/generated/scipy.stats.pearsonr.html), so you are going to send in two ordered lists of values, the populations from the wikipedia_data.html file and the win/loss ratio for a given sport in the same order. Average the win/loss ratios for those cities which have multiple teams of a single sport. Each sport is worth an equal amount in this assignment (20%\*4=80%) of the grade for this assignment. You should only use data **from year 2018** for your analysis -- this is important!
#
# ## Notes
#
# 1. Do not include data about the MLS or CFL in any of the work you are doing, we're only interested in the Big 4 in this assignment.
# 2. I highly suggest that you first tackle the four correlation questions in order, as they are all similar and worth the majority of grades for this assignment. This is by design!
# 3. It's fair game to talk with peers about high level strategy as well as the relationship between metropolitan areas and sports teams. However, do not post code solving aspects of the assignment (including such as dictionaries mapping areas to teams, or regexes which will clean up names).
# 4. There may be more teams than the assert statements test, remember to collapse multiple teams in one city into a single value!
#
# As this assignment utilizes global variables in the skeleton code, to avoid having errors in your code you can either:
#
# 1. You can place all of your code within the function definitions for all of the questions (other than import statements).
# 2. You can create copies of all the global variables with the copy() method and proceed as usual.

# %% [markdown]
# ## Question 1
# For this question, calculate the win/loss ratio's correlation with the population of the city it is in for the **NHL** using **2018** data.

# %%
import pandas as pd
import numpy as np
import scipy.stats as stats
import re

nhl_df=pd.read_csv("Assets/nhl.csv")
cities=pd.read_html("Assets/wikipedia_data.html")[1]
cities=cities.iloc[:-1,[0,3,5,6,7,8]]

cities = cities.replace(to_replace="\s\[[^)]*\]", value= "", regex= True )
cities = cities.replace(to_replace="(?<=\w)\d", value="", regex=True)

cities.rename(columns = {'Population (2016 est.)[8]': 'Population 2016'}, inplace=True)

def nhl_correlation(): 
    # YOUR CODE HERE
    raise NotImplementedError()
    
    population_by_region = [] # pass in metropolitan area population from cities
    win_loss_by_region = [] # pass in win/loss ratio from nhl_df in the same order as cities["Metropolitan area"]

    assert len(population_by_region) == len(win_loss_by_region), "Q1: Your lists must be the same length"
    assert len(population_by_region) == 28, "Q1: There should be 28 teams being analysed for NHL"
    
    return stats.pearsonr(population_by_region, win_loss_by_region)

cities
# Out:
#          Metropolitan area Population 2016                    NFL  \
# 0            New York City               2    Giants Jets[note 1]
# 1              Los Angeles               1  Rams Chargers[note 4]
# 2   San Francisco Bay Area               6   4ers Raiders[note 6]
# 3                  Chicago               9          Bears[note 8]
# 4        Dallas–Fort Worth               7                Cowboys
# 5         Washington, D.C.               6               Redskins
# 6             Philadelphia               6                 Eagles
# 7                   Boston               4       Patriots[note 1]
# 8   Minneapolis–Saint Paul               3                Vikings
# 9                   Denver               2                Broncos
# 10   Miami–Fort Lauderdale               6               Dolphins
# 11                 Phoenix               4              Cardinals
# 12                 Detroit               4                  Lions
# 13                 Toronto               5                      —
# 14                 Houston               6         Texans[note 2]
# 15                 Atlanta               5                Falcons
# 16          Tampa Bay Area               3             Buccaneers
# 17              Pittsburgh               2               Steelers
# 18               Cleveland               2         Browns[note 2]
# 19                 Seattle               3               Seahawks
# 20              Cincinnati               2                Bengals
# 21             Kansas City               2                 Chiefs
# 22               St. Louis               2               [note 4]
# 23               Baltimore               2         Ravens[note 4]
# 24               Charlotte               2               Panthers
# 25            Indianapolis               2                  Colts
# 26               Nashville               1                 Titans
# 27               Milwaukee               1               [note 5]
# 28             New Orleans               1                 Saints
# 29                 Buffalo               1          Bills[note 5]
# 30                Montreal               4                      —
# 31               Vancouver               2                      —
# 32                 Orlando               2                      —
# 33                Portland               2                      —
# 34                Columbus               2                      —
# 35                 Calgary               1                      —
# 36                  Ottawa               1                      —
# 37                Edmonton               1                      —
# 38          Salt Lake City               1                      —
# 39                Winnipeg               7                      —
# 40               San Diego               3               [note 6]
# 41             San Antonio               2               [note 6]
# 42              Sacramento               2                      —
# 43               Las Vegas               2               [note 6]
# 44            Jacksonville               1                Jaguars
# 45           Oklahoma City               1                      —
# 46                 Memphis               1               [note 6]
# 47                 Raleigh               1                      —
# 48               Green Bay               3                Packers
# 49                Hamilton               7                      —
# 50                  Regina               2                      —
#
#                      MLB                NBA                               NHL
# 0   Yankees Mets[note 2]        Knicks Nets  Rangers Islanders Devils[note 3]
# 1         Dodgers Angels    Lakers Clippers                       Kings Ducks
# 2       Giants Athletics           Warriors                    Sharks[note 7]
# 3         Cubs White Sox      Bulls[note 9]                        Blackhawks
# 4                Rangers          Mavericks                             Stars
# 5      Nationals[note 1]    Wizards[note 1]                          Capitals
# 6       Phillies[note 1]               7ers                    Flyers[note 1]
# 7        Red Sox[note 1]            Celtics                            Bruins
# 8                  Twins       Timberwolves                      Wild[note 1]
# 9                Rockies    Nuggets[note 1]                 Avalanche[note 1]
# 10               Marlins               Heat                          Panthers
# 11          Diamondbacks               Suns                           Coyotes
# 12        Tigers[note 2]    Pistons[note 2]                         Red Wings
# 13             Blue Jays    Raptors[note 2]                       Maple Leafs
# 14                Astros            Rockets                                 —
# 15                Braves              Hawks                          [note 2]
# 16                  Rays                  —                         Lightning
# 17               Pirates           [note 2]                  Penguins[note 2]
# 18       Indians[note 3]  Cavaliers[note 3]                          [note 3]
# 19              Mariners           [note 3]                          [note 3]
# 20          Reds[note 3]           [note 3]                                 —
# 21        Royals[note 3]           [note 3]                          [note 3]
# 22     Cardinals[note 4]           [note 4]                     Blues[note 4]
# 23       Orioles[note 4]           [note 4]                                 —
# 24                     —    Hornets[note 4]                                 —
# 25              [note 5]     Pacers[note 5]                                 —
# 26                     —                  —                         Predators
# 27       Brewers[note 5]              Bucks                                 —
# 28                     —   Pelicans[note 5]                                 —
# 29              [note 5]           [note 5]                            Sabres
# 30              [note 5]                  —                         Canadiens
# 31                     —           [note 6]                           Canucks
# 32                     —              Magic                                 —
# 33                     —      Trail Blazers                                 —
# 34                     —                  —                      Blue Jackets
# 35                     —                  —                            Flames
# 36                     —                  —                          Senators
# 37                     —                  —                            Oilers
# 38                     —               Jazz                                 —
# 39                     —                  —                      Jets[note 6]
# 40                Padres           [note 6]                                 —
# 41                     —              Spurs                                 —
# 42                     —              Kings                                 —
# 43                     —                  —                    Golden Knights
# 44                     —                  —                                 —
# 45                     —    Thunder[note 6]                                 —
# 46                     —          Grizzlies                                 —
# 47                     —                  —                        Hurricanes
# 48                     —                  —                                 —
# 49                     —                  —                          [note 7]
# 50                     —                  —                                 —

# %%
columns_to_keep = ['Metropolitan area']
nhl_cities = cities[]

# %% [markdown]
# ## Note:
# Here we see that we have several teams for each region.

# %%
nhl_df = nhl_df[nhl_df["year"] == 2018]
nhl_df.head(nhl_df.shape[0])
# Out:
#                       team                     GP                      W  \
# 0        Atlantic Division      Atlantic Division      Atlantic Division
# 1     Tampa Bay Lightning*                     82                     54
# 2           Boston Bruins*                     82                     50
# 3     Toronto Maple Leafs*                     82                     49
# 4         Florida Panthers                     82                     44
# 5        Detroit Red Wings                     82                     30
# 6       Montreal Canadiens                     82                     29
# 7          Ottawa Senators                     82                     28
# 8           Buffalo Sabres                     82                     25
# 9    Metropolitan Division  Metropolitan Division  Metropolitan Division
# 10    Washington Capitals*                     82                     49
# 11    Pittsburgh Penguins*                     82                     47
# 12    Philadelphia Flyers*                     82                     42
# 13  Columbus Blue Jackets*                     82                     45
# 14      New Jersey Devils*                     82                     44
# 15     Carolina Hurricanes                     82                     36
# 16      New York Islanders                     82                     35
# 17        New York Rangers                     82                     34
# 18        Central Division       Central Division       Central Division
# 19    Nashville Predators*                     82                     53
# 20          Winnipeg Jets*                     82                     52
# 21         Minnesota Wild*                     82                     45
# 22     Colorado Avalanche*                     82                     43
# 23         St. Louis Blues                     82                     44
# 24            Dallas Stars                     82                     42
# 25      Chicago Blackhawks                     82                     33
# 26        Pacific Division       Pacific Division       Pacific Division
# 27   Vegas Golden Knights*                     82                     51
# 28          Anaheim Ducks*                     82                     44
# 29        San Jose Sharks*                     82                     45
# 30      Los Angeles Kings*                     82                     45
# 31          Calgary Flames                     82                     37
# 32         Edmonton Oilers                     82                     36
# 33       Vancouver Canucks                     82                     31
# 34         Arizona Coyotes                     82                     29
#
#                         L                     OL                    PTS  \
# 0       Atlantic Division      Atlantic Division      Atlantic Division
# 1                      23                      5                    113
# 2                      20                     12                    112
# 3                      26                      7                    105
# 4                      30                      8                     96
# 5                      39                     13                     73
# 6                      40                     13                     71
# 7                      43                     11                     67
# 8                      45                     12                     62
# 9   Metropolitan Division  Metropolitan Division  Metropolitan Division
# 10                     26                      7                    105
# 11                     29                      6                    100
# 12                     26                     14                     98
# 13                     30                      7                     97
# 14                     29                      9                     97
# 15                     35                     11                     83
# 16                     37                     10                     80
# 17                     39                      9                     77
# 18       Central Division       Central Division       Central Division
# 19                     18                     11                    117
# 20                     20                     10                    114
# 21                     26                     11                    101
# 22                     30                      9                     95
# 23                     32                      6                     94
# 24                     32                      8                     92
# 25                     39                     10                     76
# 26       Pacific Division       Pacific Division       Pacific Division
# 27                     24                      7                    109
# 28                     25                     13                    101
# 29                     27                     10                    100
# 30                     29                      8                     98
# 31                     35                     10                     84
# 32                     40                      6                     78
# 33                     40                     11                     73
# 34                     41                     12                     70
#
#                      PTS%                     GF                     GA  \
# 0       Atlantic Division      Atlantic Division      Atlantic Division
# 1                    .689                    296                    236
# 2                    .683                    270                    214
# 3                    .640                    277                    232
# 4                    .585                    248                    246
# 5                    .445                    217                    255
# 6                    .433                    209                    264
# 7                    .409                    221                    291
# 8                    .378                    199                    280
# 9   Metropolitan Division  Metropolitan Division  Metropolitan Division
# 10                   .640                    259                    239
# 11                   .610                    272                    250
# 12                   .598                    251                    243
# 13                   .591                    242                    230
# 14                   .591                    248                    244
# 15                   .506                    228                    256
# 16                   .488                    264                    296
# 17                   .470                    231                    268
# 18       Central Division       Central Division       Central Division
# 19                   .713                    267                    211
# 20                   .695                    277                    218
# 21                   .616                    253                    232
# 22                   .579                    257                    237
# 23                   .573                    226                    222
# 24                   .561                    235                    225
# 25                   .463                    229                    256
# 26       Pacific Division       Pacific Division       Pacific Division
# 27                   .665                    272                    228
# 28                   .616                    235                    216
# 29                   .610                    252                    229
# 30                   .598                    239                    203
# 31                   .512                    218                    248
# 32                   .476                    234                    263
# 33                   .445                    218                    264
# 34                   .427                    208                    256
#
#                       SRS                    SOS                   RPt%  \
# 0       Atlantic Division      Atlantic Division      Atlantic Division
# 1                    0.66                  -0.07                   .634
# 2                    0.62                  -0.07                   .610
# 3                    0.49                  -0.06                   .567
# 4                   -0.01                  -0.04                   .537
# 5                   -0.48                  -0.01                   .341
# 6                   -0.68                   0.00                   .378
# 7                   -0.85                   0.00                   .372
# 8                   -0.98                   0.01                   .311
# 9   Metropolitan Division  Metropolitan Division  Metropolitan Division
# 10                   0.21                  -0.04                   .585
# 11                   0.23                  -0.04                   .573
# 12                   0.07                  -0.03                   .543
# 13                   0.11                  -0.04                   .537
# 14                   0.02                  -0.03                   .530
# 15                  -0.35                  -0.01                   .439
# 16                  -0.40                  -0.01                   .427
# 17                  -0.46                  -0.01                   .427
# 18       Central Division       Central Division       Central Division
# 19                   0.71                   0.03                   .652
# 20                   0.74                   0.02                   .622
# 21                   0.29                   0.04                   .549
# 22                   0.28                   0.04                   .518
# 23                   0.10                   0.05                   .518
# 24                   0.17                   0.04                   .506
# 25                  -0.26                   0.07                   .409
# 26       Pacific Division       Pacific Division       Pacific Division
# 27                   0.52                  -0.01                   .616
# 28                   0.24                   0.01                   .555
# 29                   0.28                   0.00                   .537
# 30                   0.44                   0.00                   .543
# 31                  -0.33                   0.03                   .470
# 32                  -0.32                   0.03                   .415
# 33                  -0.51                   0.05                   .409
# 34                  -0.53                   0.05                   .372
#
#                       ROW  year League
# 0       Atlantic Division  2018    NHL
# 1                      48  2018    NHL
# 2                      47  2018    NHL
# 3                      42  2018    NHL
# 4                      41  2018    NHL
# 5                      25  2018    NHL
# 6                      27  2018    NHL
# 7                      26  2018    NHL
# 8                      24  2018    NHL
# 9   Metropolitan Division  2018    NHL
# 10                     46  2018    NHL
# 11                     45  2018    NHL
# 12                     40  2018    NHL
# 13                     39  2018    NHL
# 14                     39  2018    NHL
# 15                     33  2018    NHL
# 16                     32  2018    NHL
# 17                     31  2018    NHL
# 18       Central Division  2018    NHL
# 19                     47  2018    NHL
# 20                     48  2018    NHL
# 21                     42  2018    NHL
# 22                     41  2018    NHL
# 23                     41  2018    NHL
# 24                     38  2018    NHL
# 25                     32  2018    NHL
# 26       Pacific Division  2018    NHL
# 27                     47  2018    NHL
# 28                     40  2018    NHL
# 29                     40  2018    NHL
# 30                     43  2018    NHL
# 31                     35  2018    NHL
# 32                     31  2018    NHL
# 33                     31  2018    NHL
# 34                     27  2018    NHL

# %%
# dropping the rows specifying the divisions: Atlantic division, Metropolitan division, Central division and Pacific division

nhl_df.drop(axis=0, index = [0, 9, 18, 26], inplace=True)
nhl_df.reset_index()
# Out:
#     index                    team  GP   W   L  OL  PTS  PTS%   GF   GA    SRS  \
# 0       1    Tampa Bay Lightning*  82  54  23   5  113  .689  296  236   0.66
# 1       2          Boston Bruins*  82  50  20  12  112  .683  270  214   0.62
# 2       3    Toronto Maple Leafs*  82  49  26   7  105  .640  277  232   0.49
# 3       4        Florida Panthers  82  44  30   8   96  .585  248  246  -0.01
# 4       5       Detroit Red Wings  82  30  39  13   73  .445  217  255  -0.48
# 5       6      Montreal Canadiens  82  29  40  13   71  .433  209  264  -0.68
# 6       7         Ottawa Senators  82  28  43  11   67  .409  221  291  -0.85
# 7       8          Buffalo Sabres  82  25  45  12   62  .378  199  280  -0.98
# 8      10    Washington Capitals*  82  49  26   7  105  .640  259  239   0.21
# 9      11    Pittsburgh Penguins*  82  47  29   6  100  .610  272  250   0.23
# 10     12    Philadelphia Flyers*  82  42  26  14   98  .598  251  243   0.07
# 11     13  Columbus Blue Jackets*  82  45  30   7   97  .591  242  230   0.11
# 12     14      New Jersey Devils*  82  44  29   9   97  .591  248  244   0.02
# 13     15     Carolina Hurricanes  82  36  35  11   83  .506  228  256  -0.35
# 14     16      New York Islanders  82  35  37  10   80  .488  264  296  -0.40
# 15     17        New York Rangers  82  34  39   9   77  .470  231  268  -0.46
# 16     19    Nashville Predators*  82  53  18  11  117  .713  267  211   0.71
# 17     20          Winnipeg Jets*  82  52  20  10  114  .695  277  218   0.74
# 18     21         Minnesota Wild*  82  45  26  11  101  .616  253  232   0.29
# 19     22     Colorado Avalanche*  82  43  30   9   95  .579  257  237   0.28
# 20     23         St. Louis Blues  82  44  32   6   94  .573  226  222   0.10
# 21     24            Dallas Stars  82  42  32   8   92  .561  235  225   0.17
# 22     25      Chicago Blackhawks  82  33  39  10   76  .463  229  256  -0.26
# 23     27   Vegas Golden Knights*  82  51  24   7  109  .665  272  228   0.52
# 24     28          Anaheim Ducks*  82  44  25  13  101  .616  235  216   0.24
# 25     29        San Jose Sharks*  82  45  27  10  100  .610  252  229   0.28
# 26     30      Los Angeles Kings*  82  45  29   8   98  .598  239  203   0.44
# 27     31          Calgary Flames  82  37  35  10   84  .512  218  248  -0.33
# 28     32         Edmonton Oilers  82  36  40   6   78  .476  234  263  -0.32
# 29     33       Vancouver Canucks  82  31  40  11   73  .445  218  264  -0.51
# 30     34         Arizona Coyotes  82  29  41  12   70  .427  208  256  -0.53
#
#       SOS  RPt% ROW  year League
# 0   -0.07  .634  48  2018    NHL
# 1   -0.07  .610  47  2018    NHL
# 2   -0.06  .567  42  2018    NHL
# 3   -0.04  .537  41  2018    NHL
# 4   -0.01  .341  25  2018    NHL
# 5    0.00  .378  27  2018    NHL
# 6    0.00  .372  26  2018    NHL
# 7    0.01  .311  24  2018    NHL
# 8   -0.04  .585  46  2018    NHL
# 9   -0.04  .573  45  2018    NHL
# 10  -0.03  .543  40  2018    NHL
# 11  -0.04  .537  39  2018    NHL
# 12  -0.03  .530  39  2018    NHL
# 13  -0.01  .439  33  2018    NHL
# 14  -0.01  .427  32  2018    NHL
# 15  -0.01  .427  31  2018    NHL
# 16   0.03  .652  47  2018    NHL
# 17   0.02  .622  48  2018    NHL
# 18   0.04  .549  42  2018    NHL
# 19   0.04  .518  41  2018    NHL
# 20   0.05  .518  41  2018    NHL
# 21   0.04  .506  38  2018    NHL
# 22   0.07  .409  32  2018    NHL
# 23  -0.01  .616  47  2018    NHL
# 24   0.01  .555  40  2018    NHL
# 25   0.00  .537  40  2018    NHL
# 26   0.00  .543  43  2018    NHL
# 27   0.03  .470  35  2018    NHL
# 28   0.03  .415  31  2018    NHL
# 29   0.05  .409  31  2018    NHL
# 30   0.05  .372  27  2018    NHL

# %%
nhl_df = nhl_df[["team", "W", "L"]]
nhl_df
# Out:
#                       team   W   L
# 1     Tampa Bay Lightning*  54  23
# 2           Boston Bruins*  50  20
# 3     Toronto Maple Leafs*  49  26
# 4         Florida Panthers  44  30
# 5        Detroit Red Wings  30  39
# 6       Montreal Canadiens  29  40
# 7          Ottawa Senators  28  43
# 8           Buffalo Sabres  25  45
# 10    Washington Capitals*  49  26
# 11    Pittsburgh Penguins*  47  29
# 12    Philadelphia Flyers*  42  26
# 13  Columbus Blue Jackets*  45  30
# 14      New Jersey Devils*  44  29
# 15     Carolina Hurricanes  36  35
# 16      New York Islanders  35  37
# 17        New York Rangers  34  39
# 19    Nashville Predators*  53  18
# 20          Winnipeg Jets*  52  20
# 21         Minnesota Wild*  45  26
# 22     Colorado Avalanche*  43  30
# 23         St. Louis Blues  44  32
# 24            Dallas Stars  42  32
# 25      Chicago Blackhawks  33  39
# 27   Vegas Golden Knights*  51  24
# 28          Anaheim Ducks*  44  25
# 29        San Jose Sharks*  45  27
# 30      Los Angeles Kings*  45  29
# 31          Calgary Flames  37  35
# 32         Edmonton Oilers  36  40
# 33       Vancouver Canucks  31  40
# 34         Arizona Coyotes  29  41

# %%
nhl_df["W"] = pd.to_numeric(nhl_df["W"])
nhl_df["L"] = pd.to_numeric(nhl_df["L"])
nhl_df["W/L Ratio"] = nhl_df["W"]/nhl_df["L"]
nhl_df
# Out:
#                       team   W   L  W/L Ratio
# 1     Tampa Bay Lightning*  54  23   2.347826
# 2           Boston Bruins*  50  20   2.500000
# 3     Toronto Maple Leafs*  49  26   1.884615
# 4         Florida Panthers  44  30   1.466667
# 5        Detroit Red Wings  30  39   0.769231
# 6       Montreal Canadiens  29  40   0.725000
# 7          Ottawa Senators  28  43   0.651163
# 8           Buffalo Sabres  25  45   0.555556
# 10    Washington Capitals*  49  26   1.884615
# 11    Pittsburgh Penguins*  47  29   1.620690
# 12    Philadelphia Flyers*  42  26   1.615385
# 13  Columbus Blue Jackets*  45  30   1.500000
# 14      New Jersey Devils*  44  29   1.517241
# 15     Carolina Hurricanes  36  35   1.028571
# 16      New York Islanders  35  37   0.945946
# 17        New York Rangers  34  39   0.871795
# 19    Nashville Predators*  53  18   2.944444
# 20          Winnipeg Jets*  52  20   2.600000
# 21         Minnesota Wild*  45  26   1.730769
# 22     Colorado Avalanche*  43  30   1.433333
# 23         St. Louis Blues  44  32   1.375000
# 24            Dallas Stars  42  32   1.312500
# 25      Chicago Blackhawks  33  39   0.846154
# 27   Vegas Golden Knights*  51  24   2.125000
# 28          Anaheim Ducks*  44  25   1.760000
# 29        San Jose Sharks*  45  27   1.666667
# 30      Los Angeles Kings*  45  29   1.551724
# 31          Calgary Flames  37  35   1.057143
# 32         Edmonton Oilers  36  40   0.900000
# 33       Vancouver Canucks  31  40   0.775000
# 34         Arizona Coyotes  29  41   0.707317

# %% [markdown]
# ## Question 2
# For this question, calculate the win/loss ratio's correlation with the population of the city it is in for the **NBA** using **2018** data.

# %%
import pandas as pd
import numpy as np
import scipy.stats as stats
import re

nba_df=pd.read_csv("assets/nba.csv")
cities=pd.read_html("assets/wikipedia_data.html")[1]
cities=cities.iloc[:-1,[0,3,5,6,7,8]]

def nba_correlation():
    # YOUR CODE HERE
    raise NotImplementedError()
    
    population_by_region = [] # pass in metropolitan area population from cities
    win_loss_by_region = [] # pass in win/loss ratio from nba_df in the same order as cities["Metropolitan area"]

    assert len(population_by_region) == len(win_loss_by_region), "Q2: Your lists must be the same length"
    assert len(population_by_region) == 28, "Q2: There should be 28 teams being analysed for NBA"

    return stats.pearsonr(population_by_region, win_loss_by_region)

cities
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[6], line 6
#       3 import scipy.stats as stats
#       4 import re
# ----> 6 nba_df=pd.read_csv("assets/nba.csv")
#       7 cities=pd.read_html("assets/wikipedia_data.html")[1]
#       8 cities=cities.iloc[:-1,[0,3,5,6,7,8]]
#
# File /private/var/containers/Bundle/Application/CFD64E72-919A-45D8-B67E-97E601DD0906/Carnets-sci.app/Library/lib/python3.11/site-packages/pandas/io/parsers/readers.py:912, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     899 kwds_defaults = _refine_defaults_read(
#     900     dialect,
#     901     delimiter,
#    (...)
#     908     dtype_backend=dtype_backend,
#     909 )
#     910 kwds.update(kwds_defaults)
# --> 912 return _read(filepath_or_buffer, kwds)
#
# File /private/var/containers/Bundle/Application/CFD64E72-919A-45D8-B67E-97E601DD0906/Carnets-sci.app/Library/lib/python3.11/site-packages/pandas/io/parsers/readers.py:577, in _read(filepath_or_buffer, kwds)
#     574 _validate_names(kwds.get("names", None))
#     576 # Create the parser.
# --> 577 parser = TextFileReader(filepath_or_buffer, **kwds)
#     579 if chunksize or iterator:
#     580     return parser
#
# File /private/var/containers/Bundle/Application/CFD64E72-919A-45D8-B67E-97E601DD0906/Carnets-sci.app/Library/lib/python3.11/site-packages/pandas/io/parsers/readers.py:1407, in TextFileReader.__init__(self, f, engine, **kwds)
#    1404     self.options["has_index_names"] = kwds["has_index_names"]
#    1406 self.handles: IOHandles | None = None
# -> 1407 self._engine = self._make_engine(f, self.engine)
#
# File /private/var/containers/Bundle/Application/CFD64E72-919A-45D8-B67E-97E601DD0906/Carnets-sci.app/Library/lib/python3.11/site-packages/pandas/io/parsers/readers.py:1661, in TextFileReader._make_engine(self, f, engine)
#    1659     if "b" not in mode:
#    1660         mode += "b"
# -> 1661 self.handles = get_handle(
#    1662     f,
#    1663     mode,
#    1664     encoding=self.options.get("encoding", None),
#    1665     compression=self.options.get("compression", None),
#    1666     memory_map=self.options.get("memory_map", False),
#    1667     is_text=is_text,
#    1668     errors=self.options.get("encoding_errors", "strict"),
#    1669     storage_options=self.options.get("storage_options", None),
#    1670 )
#    1671 assert self.handles is not None
#    1672 f = self.handles.handle
#
# File /private/var/containers/Bundle/Application/CFD64E72-919A-45D8-B67E-97E601DD0906/Carnets-sci.app/Library/lib/python3.11/site-packages/pandas/io/common.py:859, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     854 elif isinstance(handle, str):
#     855     # Check whether the filename is to be opened in binary mode.
#     856     # Binary mode does not support 'encoding' and 'newline'.
#     857     if ioargs.encoding and "b" not in ioargs.mode:
#     858         # Encoding
# --> 859         handle = open(
#     860             handle,
#     861             ioargs.mode,
#     862             encoding=ioargs.encoding,
#     863             errors=errors,
#     864             newline="",
#     865         )
#     866     else:
#     867         # Binary mode
#     868         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'assets/nba.csv'

# %% [markdown]
# ## Question 3
# For this question, calculate the win/loss ratio's correlation with the population of the city it is in for the **MLB** using **2018** data.

# %%
import pandas as pd
import numpy as np
import scipy.stats as stats
import re

mlb_df=pd.read_csv("assets/mlb.csv")
cities=pd.read_html("assets/wikipedia_data.html")[1]
cities=cities.iloc[:-1,[0,3,5,6,7,8]]

def mlb_correlation(): 
    # YOUR CODE HERE
    raise NotImplementedError()
    
    population_by_region = [] # pass in metropolitan area population from cities
    win_loss_by_region = [] # pass in win/loss ratio from mlb_df in the same order as cities["Metropolitan area"]

    assert len(population_by_region) == len(win_loss_by_region), "Q3: Your lists must be the same length"
    assert len(population_by_region) == 26, "Q3: There should be 26 teams being analysed for MLB"

    return stats.pearsonr(population_by_region, win_loss_by_region)

# %% [markdown]
# ## Question 4
# For this question, calculate the win/loss ratio's correlation with the population of the city it is in for the **NFL** using **2018** data.

# %%
import pandas as pd
import numpy as np
import scipy.stats as stats
import re

nfl_df=pd.read_csv("assets/nfl.csv")
cities=pd.read_html("assets/wikipedia_data.html")[1]
cities=cities.iloc[:-1,[0,3,5,6,7,8]]

def nfl_correlation(): 
    # YOUR CODE HERE
    raise NotImplementedError()
    
    population_by_region = [] # pass in metropolitan area population from cities
    win_loss_by_region = [] # pass in win/loss ratio from nfl_df in the same order as cities["Metropolitan area"]

    assert len(population_by_region) == len(win_loss_by_region), "Q4: Your lists must be the same length"
    assert len(population_by_region) == 29, "Q4: There should be 29 teams being analysed for NFL"

    return stats.pearsonr(population_by_region, win_loss_by_region)

# %% [markdown]
# ## Question 5
# In this question I would like you to explore the hypothesis that **given that an area has two sports teams in different sports, those teams will perform the same within their respective sports**. How I would like to see this explored is with a series of paired t-tests (so use [`ttest_rel`](https://docs.scipy.org/doc/scipy/reference/generated/scipy.stats.ttest_rel.html)) between all pairs of sports. Are there any sports where we can reject the null hypothesis? Again, average values where a sport has multiple teams in one region. Remember, you will only be including, for each sport, cities which have teams engaged in that sport, drop others as appropriate. This question is worth 20% of the grade for this assignment.

# %%
import pandas as pd
import numpy as np
import scipy.stats as stats
import re

mlb_df=pd.read_csv("assets/mlb.csv")
nhl_df=pd.read_csv("assets/nhl.csv")
nba_df=pd.read_csv("assets/nba.csv")
nfl_df=pd.read_csv("assets/nfl.csv")
cities=pd.read_html("assets/wikipedia_data.html")[1]
cities=cities.iloc[:-1,[0,3,5,6,7,8]]

def sports_team_performance():
    # YOUR CODE HERE
    raise NotImplementedError()
    
    # Note: p_values is a full dataframe, so df.loc["NFL","NBA"] should be the same as df.loc["NBA","NFL"] and
    # df.loc["NFL","NFL"] should return np.nan
    sports = ['NFL', 'NBA', 'NHL', 'MLB']
    p_values = pd.DataFrame({k:np.nan for k in sports}, index=sports)
    
    assert abs(p_values.loc["NBA", "NHL"] - 0.02) <= 1e-2, "The NBA-NHL p-value should be around 0.02"
    assert abs(p_values.loc["MLB", "NFL"] - 0.80) <= 1e-2, "The MLB-NFL p-value should be around 0.80"
    return p_values
